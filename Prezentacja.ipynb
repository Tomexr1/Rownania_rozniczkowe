# %% [markdown]
# # Modele wzrostu nowotworów oparte na równaniach różniczkowych.

# %% [markdown]
# # Plan prezentacji:
# 1. [O guzach](#o_guzach)
# 2. [Dane](#dane)
# 3. [Modele](#modele)
# 4. [Narzędzia](#narzędzia)
# 5. [Porównanie modeli rozwoju guzów](#porównanie)
# 6. [Wnioski](#wnioski)

# %% [markdown]
# # <a id="o_guzach">1. O guzach</a>

# %% [markdown]
# Naszą prezentację rozpoczniemy od zaznajomienia Czytelnika z podstawowymi pojęciami dotyczącymi chorób nowotworowych oraz wyjaśnieniu czemu wybrany przez nas temat jest wart uwagi.

# %% [markdown]
# ## 1.1 Definicja
# **Nowotwór**, med. tkanka wywodząca się z prawidłowych tkanek ustroju, lecz wskutek utrwalonych cech patologicznych rozrastająca się w sposób niekontrolowany, nie poddający się czynnikom regulującym wzrost, dojrzewanie i czynności komórek, rosnący mimo wyeliminowania przyczyny, jeżeli jest ona znana [[1]](#encyklopedia_def)

# %% [markdown]
# <div>
# <img src="attachment:Image.jpeg" width="500"/>
# </div>

# %% [markdown]
# <center>Grafika ilustrująca normalny oraz nieprawidłowy rozwój komórki. <a href="#rozwoj_kom">[2]</a></center>

# %% [markdown]
# ## 1.2 Rodzaje chorób nowotworowych

# %% [markdown]
# Nowotwory dzielimy na:
# - nowotwory łagodne (niezłośliwe)
# - nowotwory złośliwe (rak, mięsak, ...)

# %% [markdown]
# <div>
# <img src="attachment:Image%201.jpeg" width="500"/>
# </div>

# %% [markdown]
# <center>Grafika ilustrująca nowotwór łagodny i złośliwy <a href="#rozwoj_kom">[2]</a></center>

# %% [markdown]
# > ###  Nowotwór łagodny cechuje:
# > - powolny rozrost,
# > - odgraniczenie oraz nieniszczenie tkanek otaczających,
# > - brak przerzutów i nawrotów.
#
# > Nowotwór łagodny może stać się nowotworem złośliwym, zagrażającym życiu człowieka.

# %% [markdown]
# > ### Nowotwór złośliwy cechuje:
# > - gwałtowane tempo wzrostu,
# > - częste przerzuty oraz wznowy miejscowe.
#
# > Nowotwór ten, w zaawansowanym stadium, może upośledzić bądź uniemożliwić funkcjonowanie kluczowych organów doprowadzając do śmierci chorego.

# %% [markdown]
# W dalszej części prezentacji skupimy się na rakach - najczęstszej i najbardziej znanej grupie nowotworów złośliwych.

# %% [markdown]
# ## 1.3 Przyczyny choroby [[3]](#who)

# %% [markdown]
# Zmiana normalnych komórek na komórki nowotworowe jest wynikiem wzajemnego oddziaływania czynników genetycznych z trzema kategoriami czynników zewnętrznych. Czynniki te, zwane kancerogennymi, mogą uszkodzić DNA prowadząc do mutacji.

# %% [markdown]
# > ### Kancerogeny fizyczne
# > Zaliczamy do nich różnego rodzaju promieniowania.
#
# > Z najważniejszych należy wymienić:
# > - promieniowanie jonizujące,
# > - promieniowanie ultrafioletowe.

# %% [markdown]
# > ### Kancerogeny chemiczne
# >To substancje chemiczne, w przypadku których długotrawała ekspozycja prowadzi do wzrostu prawdopodobieństwa na zachorowanie na chorobę nowotworową.
#
# > Są to między innymi:
# > - azbest - materiał wykorzystywany w budownictwie,
# > - składniki dymu tytoniowego,
# > - alkohol,
# > - aflatoksyny - jako zanieczyszczenie żywności,
# > - arsen - jako zanieczyszczenie wody pitnej.

# %% [markdown]
# > ### Kancerogeny biologiczne
# > Są to infekcje wywołane przez niektóre wirusy, bakterie lub pasożyty.
#
# > Na przykład:
# > - wirus brodawczaka ludzkiego,
# > - wirus zapalenia wątroby typu B,
# > - wirus Epsteina-Barr.

# %% [markdown]
# ## 1.4 Zapobieganie [[3]](#who)

# %% [markdown]
# Obecnie około 30-50% przypadkom dałoby się zapobiec poprzez unikanie czynników ryzyka i wdrażanie strategii profilaktycznych. \
# Obciążenie chorobami nowotworowymi można również zmniejszyć poprzez wczesne wykrywanie raka, odpowiednie leczenie oraz opiekę nad pacjentami, u których rozwinął się nowotwór.

# %% [markdown]
# > ### Ryzyko zachorowania możemy zmniejszyć poprzez:
# > - niezażywanie tytoniu,
# > - utrzymywanie prawidłowej masy ciała,
# > - stosowanie zdrowej diety,
# > - regularną aktywność fizyczną,
# > - ograniczenie spożycia alkoholu,
# > - zaszczepienie przeciwko HPV i wirusowemu zapaleniu wątroby typu B (w przypadku należenia do grupy, dla której szczepienie jest zalecane)
# > - unikanie ekspozycji na promieniowanie ultrafioletowe i stosowanie środków ochrony przeciwsłonecznej,
# > - zapewnienie bezpiecznego stosowania promieniowania w opiece zdrowotnej,
# > - zmniejszenie narażenia na zanieczyszczenie powietrza.

# %% [markdown]
# > ### Wczesne wykrywanie
# > Śmiertelność z powodu raka zmniejsza się, gdy choroba jest wcześnie wykryta i leczona. Istnieją dwa elementy wczesnego wykrywania: wczesna diagnoza i badania przesiewowe.
#
# > #### Wczesna diagnoza
# > Wcześnie postawiona diagnoza zwiększa szanse na skuteczność stosowanego leczenia, tym samym poprawiając rokowania pacjenta. \
# > Ważnymi jej elementami są:
# > - świadomość obajwów choroby oraz konieczności konsultacji ze specjalistą w razie ich wystąpienia,
# > - dostęp do usług diagnostycznych,
# > - terminowe skierowanie na leczenie.
#
# >#### Badania przesiewowe
# > Badania przesiewowe mają na celu identyfikację osób z wynikami sugerującymi określony nowotwór lub stan przednowotworowy, zanim wystąpią u nich objawy. W przypadku wykrycia nieprawidłowości podczas badań przesiewowych przeprowadza się dalsze testy w celu postawienia ostatecznej diagnozy. \
# > Metoda ta nie jest skuteczna dla wszytskich rodzajów raka oraz wymaga specjalistycznego sprzętu i wykwalifikowanego personelu. Z&nbsp;tego względu wybór pacjentów do badań opiera się na wieku i wystepowaniu czynników ryzyka.

# %% [markdown]
# ## 1.5 Leczenie [[[5]](#metody1), [[7]](#metody2)]

# %% [markdown]
# Leczenie dobiera się indywidualnie, biorąc pod uwagę typ nowotworu oraz stan chorego. Głównym celem jest zazwyczaj wyleczenie raka lub znaczne przedłużenie życia pacjenta.

# %% [markdown]
# > ## Metody leczenia

# %% [markdown]
#    > ### Leczenie systemowe
#    > Polega na podawaniu leków działających ogólnoustrojowo. Wyróżniamy następujące sposoby leczenia systemowego:
#    > - ### Chemioterapia
#    > Polega na podawaniu do organizmu chorego leków cytostatycznych, które zaburzają proces podziału szybko dzielących się komórek, tym samym powodując ich śmierć. Niszczone są w ten sposób komórki nowotworowe. Do jej skutków ubocznych należy oddziaływanie na zdrowe i szybko dzielące się komórki, np. komórki szpiku kostnego, przewodu pokarmowego, włosów.

# %% [markdown]
# ![Represent-MRI-graphs-of-rectal-cancer-before-and-after-chemotherapy-in-the-same.png](attachment:Represent-MRI-graphs-of-rectal-cancer-before-and-after-chemotherapy-in-the-same.png)

# %% [markdown]
# <center>Zdjęcie MRI raka odbytnicy przed i po chemioterapii <a href="#po_chemii">[4]</a></center>

# %% [markdown]
# > - ### Hormonoterapia
# > Wykorzystywana jest w przypadku nowotworów hormonozależnych. Polega na stosowaniu leków wpływających na zmianę środowiska hormonalnego, co umożliwia hamowanie wzrostu nowotworu.
# > - ### Immunoterapia
# > Metoda polega na zastosowaniu leków wpływających na układ odpornościowy. Ich działanie doprowadza do nasilenia odpowiedzi immunologicznej pacjenta lub do zahamowania rozwoju raka wskutek blokowania jego czynników wzrostu.
# > - ### Leczenie celowane
# > Oddziaływuje przede wszystkim na komórki nowotworowe, oszczędzając większość komórek prawidłowych. Aby ją zastosować, trzeba zidentyfikować profil molekularny komórek nowotworowych i znaleźć różnice pomiędzy nimi, a komórkami prawidłowymi. Przeprowadza się analizę genetyczną komórki nowotworowej, a następnie określa się cel molekularny, jakim jest zmiana w jej budowie. W ten sposób dobiera się lek, który blokując odpowiednie receptory, pozwala zahamować rozwój choroby.

# %% [markdown]
# > ### Leczenie chirurgiczne
# > Operacje chirurgiczne wykonywane są jako jedyna forma leczenia (np. we wczesnej fazie raka jelita grubego) lub jako element terapii skojarzonej (np. z radioterapią, chemioterapią). \
# > Zabiegi przeprowadzane są z różnych wskazań:
# > - jako zabiegi radykalnego leczenia miejscowego,
# > - jako zabiegi zmniejszające masę guza w skojarzeniu z innymi sposobami leczenia (np. z chemioterapią),
# > - jako zabiegi interwencyjne (np. w przypadku niedrożności przewodu pokarmowego).

# %% [markdown]
# > ### Chirurgia robotowa
# > Rozwój technologii niesie za sobą możliwość wykorzystywania zrobotyzowanych instrumentów chirurgicznych. Urządzenia&nbsp;te&nbsp;charakteryzują się wyjątkową precyzją oraz małą inwazyjnością, co skutkuje wysoką efektywnością operacji i&nbsp;znacznym ograniczeniem ryzyka powikłań pooperacyjnych. Chirurgia robotowa sprawdza się przy wykonywaniu zabiegów m.in.&nbsp;w&nbsp;obszarze urologii, ginekologii i chirurgii ogólnej.

# %% [markdown]
# ![xda_vinci_piaseczno.jpg.pagespeed.ic.uQVTBGbcNf.jpg.webp](attachment:xda_vinci_piaseczno.jpg.pagespeed.ic.uQVTBGbcNf.jpg.webp)

# %% [markdown]
# <center>Zdjęcie przedstawia robota chirurgicznego da Vinci znajdującego się w szpitalu Św. Anny w Piasecznie. Za&nbsp;pomocą urządzenia placówka realizuje zabiegi usunięcia guza nerki, prostaty i pęcherza moczowego. <a href="#davinci">[6]</a></center>

# %% [markdown]
# > ### Radioterapia
# > Radioterapia jest sposobem miejscowego leczenia nowotworów przy wykorzystaniu energii promienistej. Do tego celu używa się urządzeń emitujących promieniowanie X (tzw. promieniowanie rentgenowskie), promieniowanie gamma, elektrony, cząstki alfa oraz promieniowanie neutronowe. \
# > Ze względu na sposób napromieniowania wyróżniamy:
# > - teleterapię, w której źródło promieniowania umieszczone jest w pewnej odległości od guza,
# > - brachyterapię, w której źródło promieniowania umieszczone jest w bezpośredniej bliskości guza.

# %% [markdown]
# > ### Medycyna nuklearna [[8]](#nuklearna)
# > To metoda, w której stosuje się specjalne leki (zwane radiofarmaceutykami) zawierające izotopy promieniotwórcze. Izotop emitujujący promieniowanie o dużej energii, ale o małym zasięgu wprowadzany jest do wnętrza nowotworu. W ten sposób niszczone są nieprawidłowe komórki oraz minimalizowane skutki uboczne.

# %% [markdown]
# > ### Opieka paliatywna
# > Stosowana u nieuleczalnie chorych. Leczenie ma na celu złagodzenie, a nie wyleczenie, objawów i cierpienia spowodowanego chorobą nowotworową. Może przyczynić się do poprawy komfortu oraz jakości życia.

# %% [markdown]
# ## 1.6 Statystyki

# %% [markdown]
# <font size=3>Poniższe grafiki przedstawiają statystyki dotyczące liczby zachorowań i zgonów na nowotwory złośliwe w Polsce. <br> Wykresy pochodzą z raportu z roku 2019, umieszczonego na stronie Krajowego Rejestru Nowotworów. <a href="#stats">[9]</a></font>

# %% [markdown]
# ![Screenshot%202023-12-12%20at%2022.50.36.png](attachment:Screenshot%202023-12-12%20at%2022.50.36.png)

# %% [markdown]
# ![Screenshot%202023-12-12%20at%2022.53.24.png](attachment:Screenshot%202023-12-12%20at%2022.53.24.png)

# %% [markdown]
# ![Screenshot%202023-12-12%20at%2022.55.31.png](attachment:Screenshot%202023-12-12%20at%2022.55.31.png)

# %% [markdown]
# # <a id="dane">2. Dane</a>

# %% [markdown]
# ## 2.1. Etyka

# %% [markdown]
# ## 2.2 Dane eksperymentalne

# %% [markdown]
# > ### Dane dotyczące piersi mierzone za pomocą fluorescencji
# Dane eksperymentalne poddane analizie dostępne są na publicznym repozytorium [[11]](#myszki_fluo). Dotyczą one wzrostu guza, obejmują ludzkie komórki MDA-MB-231 stabilnie transfekowane* lentiwirusem dTomato. Komórki wszczepiono 6-tygodniowym samicom myszy laboratoryjnych ortotopowo (80 000 komórek przy wstrzyknięciu) do poduszek tłuszczowych sutka. Rozmiar guza był regularnie monitorowany za pomocą obrazowania fluorescencyjnego. Dane obejmują łącznie 64 obserwacje.
#
# > \* transfekcja − proces wprowadzenia obcego DNA lub RNA do komórki eukariotycznej

# %%
# fluorescent imaging of a tumor

# %% [markdown]
# > ### Dane dotyczące piersi mierzone na podstawie objętości
# Dane eksperymentalne poddane analizie dostępne są na publicznym repozytorium [[12]](#myszki_piersi). W badaniu użyto ludzkich komórek LM2-4$^{ \operatorname{LUC+}}$ potrójnie ujemnego raka piersi pierwotnie pochodzących z komórek MDA-MB-231. Komórki LM2-4$^{ \operatorname{LUC+}}$ wszczepiono ortotopowo (10$^6$ komórek na wstrzyknięcie) do prawych pachwinowych poduszek tłuszczowych u 6-8-tygodniowych samic myszy z ciężkim złożonym niedoborem odporności (SCID). Rozmiar guza mierzono regularnie za pomocą suwmiarki (do maksymalnej objętości 2cm$^3$). Największą ($L$) i najmniejszą ($w$) średnicę zmierzono podskórnie za pomocą suwmiarki, a następnie użyto wzoru $V = \frac{π}{6}w^2L$ do obliczenia objętości elipsoidy. Dane zostały zebrane z ośmiu eksperymentów z łączną liczbą 581 obserwacji. Myszy należały do grupy kontrolnej, której podawano nośnik (ang. vehicle) [[[13]](#piersi_badanie1), [[14]](#piersi_badanie2)].

# %% [markdown]
# > ### Dane dotyczące płuc mierzone na podstawie objętości
# Dane eksperymentalne poddane analizie dostępne są na publicznym repozytorium [[15]](#myszki_obj). Komórki mysiego raka płuc Lewisa, pobrane od szczepu C57BL/6 myszy laboratoryjnych [[16]](#myszki_pluca), wszczepiono podskórnie ($10^6$ komórek we wstrzyknięciu) na ogonowej połowie grzbietu u&nbsp;znieczulonych 6-8-tygodniowych myszy C57BL/6. Rozmiar guza mierzono regularnie, jak opisano powyżej (do maksymalnej objętości&nbsp;1.5cm$^3$). Dane zostały zebrane z dwóch eksperymentów z łączną liczbą 188 obserwacji.

# %% [markdown]
# ## 2.3 Wykresy

# %%
# krótki komentarz, co pokazuje każdy wykres

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
plt.rcParams['figure.figsize'] = [14, 7]

# %%
breast_fluo_data = pd.read_csv('Data/breast_fluo_data.txt', sep='\t').set_index('ID')  # obs: photon/s
breast_vol_data = pd.read_csv('Data/breast_vol_data.txt', sep='\t').set_index('ID')  # obs: V= pi/6 * w^2 * L, w/L = smallest/largest diameter
lung_vol_data = pd.read_csv('Data/lung_vol_data.txt', sep='\t')  # obs: V= pi/6 * w^2 * L, w/L = smallest/largest diameter

# %%
breast_fluo_data.reset_index().plot(x='Time', y='Observation',kind='scatter', c='ID', colormap='viridis')
# Out:
# <Axes: xlabel='Time', ylabel='Observation'>

# %%
breast_fluo_data.reset_index().pivot(index='Time', columns='ID', values='Observation').plot()  # line
# Out:
# <Axes: xlabel='Time'>

# %%
breast_vol_data.reset_index().plot(x='Time', y='Observation',kind='scatter', c='ID', colormap='viridis')
# Out:
# <Axes: xlabel='Time', ylabel='Observation'>

# %%
breast_vol_data.reset_index().pivot(index='Time', columns='ID', values='Observation').plot(legend=False)  # line
# Out:
# <Axes: xlabel='Time'>

# %%
lung_vol_data.reset_index().plot(x='Time', y='Observation',kind='scatter', c='ID', colormap='viridis')
# Out:
# <Axes: xlabel='Time', ylabel='Observation'>

# %%
lung_vol_data.reset_index().pivot(index='Time', columns='ID', values='Observation').plot()
# Out:
# <Axes: xlabel='Time'>

# %% [markdown]
# # <a id="modele"> 3. Modele </a>

# %%
# dzięki takiemu sposobowi numeracji możemy odwoływać się do równań w innych komórkach, jak na razie niewykorzystane

# %% [markdown]
# <script type="text/javascript"
#   src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.0/MathJax.js?config=TeX-AMS_CHTML">
# </script>
# <script type="text/x-mathjax-config">
#   MathJax.Hub.Config({
#     tex2jax: {
#       inlineMath: [['$','$'], ['\\(','\\)']],
#       processEscapes: true},
#       jax: ["input/TeX","input/MathML","input/AsciiMath","output/CommonHTML"],
#       extensions: ["tex2jax.js","mml2jax.js","asciimath2jax.js","MathMenu.js","MathZoom.js","AssistiveMML.js", "[Contrib]/a11y/accessibility-menu.js"],
#       TeX: {
#       extensions: ["AMSmath.js","AMSsymbols.js","noErrors.js","noUndefined.js"],
#       equationNumbers: {
#       autoNumber: "AMS"
#       }
#     }
#   });
# </script>

# %% [markdown]
# ## 3.1 Modele, które wykorzystamy

# %% [markdown]
#  > ### Model Malthusa (wykładniczy)
# Zgodnie z jego koncepcją zmiana objętości $V$ w czasie $t$ jest proporcjonalna do wielkości tej objętości. Przy współczynniku proporcjonalności wynoszącym $k$ możemy zapisać
# >
# > $$
# \begin{equation}
#     V'=kV \label{eq1}\tag{1}
# \end{equation}
# $$
#  > ### Rozwiązanie
# Zapisujemy równanie ([1](#mjx-eqn-eq1))
# $$
# \begin{equation}
#     \frac{\operatorname{d}\!V}{V} = k\operatorname{d}\!t
# \end{equation}
# $$
# Całkując obustronnie
# $$
# \begin{equation}
#     \int{\frac{\operatorname{d}\!V}{V}} = \int{k\operatorname{d}\!t}
# \end{equation}
# $$
# Skoro V jest nieujemne
# $$
# \begin{equation}
#     \ln{V} = kt + C
# \end{equation}
# $$
# Czyli
# $$
# \begin{equation}
#     V = \tilde{C}e^{kt}
# \end{equation}
# $$

# %% [markdown]
# >### Model Verhulsta (logistyczny)
# Jest to zmodyfikowany model Malthusa uwzględniający ograniczoną pojemność organizmu. Zakładamy w nim, że tempo przyrostu objętości maleje wraz z rozrostem guza. Wyrażamy go wzorem
# >
# > \begin{equation}
# % \tag{2}
#     V' = rV(1-\frac{V}{K}) \label{eq2}\tag{2},
# \end{equation}
# gdzie: <br>
# $V$ - objętość guza,<br>
# $r$ - współczynnik tempa wzrostu, <br>
# $K$ - maksymalna objętość nowotworu (nieunaczynionego).
# > ### Rozwiązanie
# >
# > Zapisujemy równanie ([2](#mjx-eqn-eq2))
# >
# > \begin{equation}
#      \frac{\operatorname{d}\!V}{\operatorname{d}\!t} = rV(\frac{K - V}{K})
# \end{equation}
# >
# > Rozdzieląc zmienne
# >
# > \begin{equation}
#     \frac{K \operatorname{d}\!V}{V (K - V)} = r\operatorname{d}\!t
# \end{equation}
# >
# > Całkując obustronnie
# >
# > \begin{equation}
#     \int {\frac{K \operatorname{d}\!V}{V (K - V)}} = \int{r\operatorname{d}\!t}
# \end{equation}
# >
# > Rozkładając na ułamki proste
# >
# > \begin{equation}
#     \int {\frac{\operatorname{d}\!V}{(K - V)}} + \int {\frac{\operatorname{d}\!V}{K}} = \int{r\operatorname{d}\!t}
# \end{equation}
# >
# > Stąd
# >
# > \begin{equation}
#     \ln{\frac{V}{K-V}} = rt + \ln{C}
# \end{equation}
# >
# > Ostatecznie
# >
# > \begin{equation}
#     V = \frac{e^{rt}CK}{1+e^{rt}C}
# \end{equation}

# %% [markdown]
# > ### Model Gompertza [[10]](#gompertz)
# Funkcja wykorzystywana, gdy badane wielkości charakteryzują się najpierw etapem przyśpieszonego wzrostu, który następnie jest zwalniany. Stosując&nbsp;oznaczenia przyjęte wyżej, model możemy wyrazić za pomocą wzoru
# >
# >\begin{equation}
#     V' = rV\ln{\frac{K}{V}} \label{eq3}\tag{3},
# \end{equation}
# >
# > ### Rozwiązanie
# Zapisujemy równanie ([3](#mjx-eqn-eq3))
# >
# >\begin{equation}
#     \frac{\operatorname{d}\!V}{\operatorname{d}\!t} = rV\ln{\frac{K}{V}}.
# \end{equation}
# >
# > Podstawiamy $u = \ln{\frac{K}{V}}$ oraz $\frac{\operatorname{d}\!u}{\operatorname{d}\!t} = \frac{V}{K} \big(-\frac{K}{V^2}\big) \frac{\operatorname{d}\!V}{\operatorname{d}\!t}$.
# >
# > Wtedy równanie przyjmuje postać
# >
# >\begin{equation}
#     \frac{\operatorname{d}\!u}{\operatorname{d}\!t} = -ru.
# \end{equation}
# >
# >Rozdzielamy zmienne i całkujemy
# >
# >\begin{equation}
#     \int{\frac{\operatorname{d}\!u}{u}} = \int{-r\operatorname{d}\!t}.
# \end{equation}
# >
# >Stąd
# >
# >\begin{equation}
#    u = Ce^{-rt}.
# \end{equation}
# >
# >Czyli
# >
# >\begin{equation}
#     V = \tilde{C}K\exp{({-e^{-rt}})}.
# \end{equation}

# %%
# Model lepszy - latex

# %% [markdown]
# ## 3.2 Implementacja modeli

# %%
def malthus_diff(t, y):
    k = 0.27 
    return y * k


def malthus(t, C, k):
    return C * np.exp(k*t)


def verhulst_diff(t, y):
    K = 3000
    r = 0.32
    return r * y * (1 - y/K)


# def verhulst(


def gompertz_diff(t, y):
    K = 3000  # K = V0 * exp(r0/b)
    r = 0.13  # r = r0/ln(K/V0)
    return r * y * np.log(K / y)


def gompertz(t, V0, r0, b):
    return V0 * np.exp(r0/b * (1 - np.exp(t)))

# %% [markdown]
# # <a id="narzędzia">4. Narzędzia</a>

# %% [markdown]
# W tej sekcji spróbujemy znaleźć i zaimplementować metodę rozwiązaywania równań różniczkowych numerycznie.

# %% [markdown]
# ## 4.1 Metoda jawna Eulera
# W tej metodzie $y_n$ jest dane wzorem
# \begin{equation}
#     y_n = y_{n-1} + hf(t_{n-1}, y_{n-1}).
# \end{equation}

# %%
def euler_method(f, x0, y0, h, n):
    """
    Znajduje rozwiązanie równania y' = f(x, y) metodą jawną Eulera na przedziale [x0, x0 + nh].
    
    :param f: funkcja prawej strony równania y' = f(x, y)
    :param x0: parametr początkowy x
    :param y0: parametr początkowy y
    :param h: krok
    :param n: liczba kroków
    :return: krotka (xs, ys) zawierająca listy kolejnych wartości x i y
    """
    x = x0
    y = y0
    xs, ys = [x0], [y0]
    for i in range(n-1):
        y += h * f(x, y)
        x += h
        xs.append(x)
        ys.append(y)
    return xs, ys

# %% [markdown]
# ## 4.2 Metoda niejawna Eulera
#
# W metodzie niejawnej Eulera $y_n$ jest dane wzorem
#
# \begin{equation}
#     y_n = y_{n-1} + hf(t_n,y_n).
# \end{equation}
#
#
# Zatem w każdym kroku pętli trzeba rozwiązać równianie nieliniowe $y_n - y_{n-1} - hf(t_n,y_n) = 0$ dla zmiennej $y_n$. W celu znalezienia pierwiastka tego równania będziemy korzystać z metody Newtona (Newtona-Raphsona). Polega ona na iteratywnym znajdowaniu coraz lepszego przybliżenia pierwiastka. Algorytm zaczyna z funkcją $f$, jej pochodną $f'$ oraz pewną wartością startową $x_0$ (będziemy zaczynali z $x_0 = y_{n-1}$). Jeżeli $f$ spełnia odpowiednie warunki, to dowodzi się, że kolejne przybliżenia pierwiastka dane są wzorem rekurencyjnym
#
# \begin{equation}
#     x_{k+1} = x_k - \frac{f(x_k)}{f'(x_k)}, k = 1, 2, 3, \dotsc .
# \end{equation}
#
# Będziemy brać przybliżenie pierwiastka dla $k=99$. Dodatkowo pochodną $f'(x_k)$ będziemy przybliżać numerycznie przez $f'(x_k) \approx \frac{f(x_k+0.0001)-f(x_k)}{0.0001}$.

# %%
def backward_euler_method(f, x0, y0, h, n):
    """
    Znajduje rozwiązanie równania y' = f(x, y) metodą niejawną Eulera na przedziale [x0, x0 + nh].
    
    :param f: funkcja prawej strony równania y' = f(x, y)
    :param x0: parametr początkowy x
    :param y0: parametr początkowy y
    :param h: krok
    :param n: liczba kroków
    :return: krotka (xs, ys) zawierająca listy kolejnych wartości x i y
    """
    x = x0
    y = y0
    xs, ys = [x0], [y0]
    for i in range(n-1):
        y = newton_method(lambda y: y - h * f(x, y) - ys[i], y)
        x += h
        xs.append(x)
        ys.append(y)
    return xs, ys


def newton_method(f, x0):
    """
    Znajduje miejsce zerowe funkcji f metodą Newtona.

    :param f: funkcja
    :param x0: wartość startowa
    :return: przybliżenie miejsca zerowego
    """
    x = x0
    for _ in range(100):
        x = x - f(x) / (f(x + 0.0001) - f(x)) * 0.0001
    return x

# %% [markdown]
# ## 4.3 Metoda Taylora drugiego rzędu
# Kolejną metodą, którą zaimplementujemy będzie metoda oparta o lepszą aproksymację wynikającą ze wzoru Taylora. W tym celu bierzemy przybliżenie różnicy skończonej
#
# \begin{equation}
#     \delta y(t) = \frac{1}{h} (y(t+h)-y(t)) \stackrel{T}{=} \frac{1}{h}\big(y(t) + hy'(t) + \frac{h^2}{2}y''(t) + \frac{h^3}{6}y'''(\tau) - y(t)\big) = y'(t) + \frac{h}{2}y''(t) + \frac{h^2}{6}y'''(\tau), \text{gdzie} \: \tau \in (t, t+h).
# \end{equation}
#
# Teraz dyskretyzujemy, przybliżamy $y'$ przez $\delta y$ oraz pomijamy resztę
#
# \begin{equation}
#     y'(t_{n}) \approx \frac{y_{n+1}-y_n}{h} = \delta y(t_n) \approx y'(t_n) + \frac{h}{2}y''(t_n),
# \end{equation}
#
# stąd wyznaczamy $y_{n+1}$
#
# \begin{equation}
#     y_{n+1} = y_n + hy'_n + \frac{h^2}{2}y''_n.
# \end{equation}
#
# Przy czym $y'_n = f(t_n, y_n)$, a $y''_n$ możemy zapisać z reguły łańcucha jako $y''_n = \frac{\partial f}{\partial t} + \frac{\partial f}{\partial y}f$.

# %%
def quadratic_taylor_method(f, x0, y0, h, n):
    """
    Znajduje rozwiązanie równania y' = f(x, y) metodą Taylora kwadratową na przedziale [x0, x0 + nh].

    :param f: funkcja prawej strony równania y' = f(x, y)
    :param x0: parametr początkowy x
    :param y0: parametr początkowy y
    :param h: krok
    :param n: liczba kroków
    :return: krotka (xs, ys) zawierająca listy kolejnych wartości x i y
    """
    x = x0
    y = y0
    xs, ys = [x0], [y0]
    for i in range(n-1):
        fx = (f(x + 0.0001, y) - f(x, y)) / 0.0001
        fy = (f(x, y + 0.0001) - f(x, y)) / 0.0001
        y += h * f(x, y) + (h ** 2) / 2 * (fx + f(x, y) * fy)
        x += h
        xs.append(x)
        ys.append(y)
    return xs, ys

# %% [markdown]
# ## 4.4 Metoda środkowego punktu Eulera
# Inną metodą, która osiąga lepszy rząd przybliżenia niż metody Eulera wyprowadzone na wykładzie jest metoda środkowego punktu. Jej zaletą nad metodą Taylora jest brak konieczności obliczania pochodnych funkcji $f$. W tej metodzie chcemy oszacować nachylenie każdego kawałka krzywej gdyż zwykła metoda Eulera traci na dokładności wraz ze zwiększającym się $t$. W tym celu obliczamy $y_{k+1/2}$ przy użyciu metody Eulera, czyli
#
# \begin{equation}
#     y_{k+1/2} = y_k + \frac{h}{2}f(t_k,y_k).
# \end{equation}
#
# Następnie określamy dokładniejsze nachylenie dane wzorem $f(t_k + h/2, y_{k+1/2})$.
#
# Stąd
# \begin{equation}
#     y_{k+1} = y_k + hf(t_k + h/2, y_{k+1/2}).
# \end{equation}

# %%
def euler_midpoint_method(f, x0, y0, h, n):
    """
    Znajduje rozwiązanie równania y' = f(x, y) metodą środkowego punktu na przedziale [x0, x0 + nh].

    :param f: funkcja prawej strony równania y' = f(x, y)
    :param x0: parametr początkowy x
    :param y0: parametr początkowy y
    :param h: krok
    :param n: liczba kroków
    :return: krotka (xs, ys) zawierająca listy kolejnych wartości x i y
    """
    x = x0
    y = y0
    xs, ys = [x0], [y0]
    for i in range(n-1):
        y += h * f(x + h / 2, y + h / 2 * f(x, y))
        x += h
        xs.append(x)
        ys.append(y)
    return xs, ys

# %% [markdown]
# ## 4.5 Metoda Rungego-Kutty (IV rzędu)
# Metody Rungego-Kutty są uogólnieniem metody środkowego punktu Eulera. Najpopularniejsza jest metoda czwartego rzędu, ponieważ daje najlepsze oszacowanie w stosunku do rzędu. Metoda numeryczna jest dana wzorem
#
# \begin{equation}
#     y_{k+1} = y_k + \frac{h}{6}\big(k_0 + 2k_1 + 2k_2 + k_3\big),
# \end{equation}
#
# gdzie
# \begin{align}
#     k_0 &= f(t_k, y_k), \\
#     k_1 &= f(t_k + h/2, y_k + hk_0/2), \\
#     k_2 &= f(t_k + h/2, y_k + hk_1/2), \\
#     k_3 &= f(t_k + h, y_k + hk_2).
# \end{align}

# %%
def runge_kutta_method(f, x0, y0, h, n):
    """
    Znajduje rozwiązanie równania y' = f(x, y) metodą Runge-Kutty na przedziale [x0, x0 + nh].

    :param f: funkcja prawej strony równania y' = f(x, y)
    :param x0: parametr początkowy x
    :param y0: parametr początkowy y
    :param h: krok
    :param n: liczba kroków
    :return: krotka (xs, ys) zawierająca listy kolejnych wartości x i y
    """
    x = x0
    y = y0
    xs, ys = [x0], [y0]
    for i in range(n-1):
        k0 = f(x, y)
        k1 = f(x + h / 2, y + k0 / 2)
        k2 = f(x + h / 2, y + k1 / 2)
        k3 = f(x + h, y + k2)
        y += h / 6 * (k0 + 2 * k1 + 2 * k2 + k3)
        x += h
        xs.append(x)
        ys.append(y)
    return xs, ys

# %% [markdown]
# ## 4.6 Testy
#
# Do testu dokładności przybliżenia rozwiązań numerycznych tych modeli użyjemy wcześniej zaimplementowanego modelu Malthusa $V' = kV$, którego rozwiązaniem jest $V = Ce^{kt}$. Wybieramy parametr $k=0.27$ i w celu znalezienia $C$ skorzystamy z danych pacjenta o ID = 0.

# %%
lung_0 = lung_vol_data[lung_vol_data['ID'] == 0]
k = 0.27
C = lung_0.Observation.iloc[0] / np.exp(k * lung_0.Time.iloc[0])  # znalezienie stałej C

# %% [markdown]
# Spreparujemy teraz dane na wycinku czasu od pierwszego rekordu do ostatniego dla tego pacjenta w celu samego prztestowania dokładności zaimplementowanych metod. Następnie znajdziemy przybliżenia tych wyników przy użyciu wcześniej zaimplementowanych metod rozwiązywania równań różniczkowych. Na końcu przygotujemy stworzymy tablice zawierające błędy dla kolejnych metod i przedstawimy je na wykresie w skali log-log.

# %%
h = 10 ** (-3)  # krok czasu
n = (lung_0['Time'].iloc[-1] - lung_0['Time'][0]) / h  # ilość kroków


# Tworzymy dane
xs = np.arange(lung_0.Time.iloc[0], lung_0.Time.iloc[-1], h)
ys = [malthus(x, C, k) for x in xs]


# Wyniki oszacowań dla kolejnych metod
xs1, ys1 = euler_method(malthus_diff, lung_0['Time'][0], lung_0['Observation'][0], h, int(n))
xs2, ys2 = backward_euler_method(malthus_diff, lung_0['Time'][0], lung_0['Observation'][0], h, int(n))
xs3, ys3 = quadratic_taylor_method(malthus_diff, lung_0['Time'][0], lung_0['Observation'][0], h, int(n))
xs4, ys4 = euler_midpoint_method(malthus_diff, lung_0['Time'][0], lung_0['Observation'][0], h, int(n))
xs5, ys5 = runge_kutta_method(malthus_diff, lung_0['Time'][0], lung_0['Observation'][0], h, int(n))


# Błędy dla kolejnych metod
ys1_err = [abs(y) for y in np.subtract(ys1, ys)]
ys2_err = [abs(y) for y in np.subtract(ys2, ys)]
ys3_err = [abs(y) for y in np.subtract(ys3, ys)]
ys4_err = [abs(y) for y in np.subtract(ys4, ys)]
ys5_err = [abs(y) for y in np.subtract(ys5, ys)]

# %%
fig, ax = plt.subplots()
# ax.plot(xs, ys, label="Dane")
ax.plot(xs, ys1_err, label='Euler method', alpha=0.5, marker='D')
ax.plot(xs, ys2_err, label='Backward Euler method', alpha=0.5)
ax.plot(xs, ys3_err, label='Taylor method', alpha=0.5)
ax.plot(xs, ys4_err, label='Midpoint method', alpha=0.5)
ax.plot(xs, ys5_err, label='Runge Kutta', alpha=0.5)
fig.legend()
plt.title('Id = 0')
plt.xlabel('Czas [dzień]')
plt.ylabel('Objętość guza [$mm^3$]')
plt.yscale('log')

# %%
C = lung_1.Observation.iloc[0] / 3000 / np.exp(-np.exp(-0.13 * lung_1.Time.iloc[0]))
D = lung_1.Observation.iloc[0] / np.exp(0.27 * lung_1.Time.iloc[0])

# %%
def gomp(t):
    return C * 3000 * np.exp(-np.exp(0.93*t))



def mal(t):
    return D * np.exp(0.27 * t)

# %%
# np 
h = 10 ** (-1)

lung_1 = lung_vol_data[lung_vol_data['ID'] == 0]
n = (lung_1['Time'].iloc[-1] - lung_1['Time'][0]) / h


xs1, ys1 = backward_euler_method(gompertz_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs2, ys2 = euler_method(gompertz_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs3, ys3 = quadratic_taylor_method(gompertz_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs4, ys4 = quadratic_taylor_method(malthus_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs5, ys5 = quadratic_taylor_method(verhulst_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs6, ys6 = euler_midpoint_method(gompertz_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))
xs7, ys7 = runge_kutta_method(gompertz_diff, lung_1['Time'][0], lung_1['Observation'][0], h, int(n))

# dane dla K = 3000, r = 0.13 i danych lung_1 id=1, model grompetza

xs = np.arange(lung_1.Time.iloc[0], lung_1.Time.iloc[-1], h)
# xs = np.arange(lung_1.Time.iloc[0], 20000, h)
ys = [mal(t) for t in xs]


fig, ax = plt.subplots()

ax.plot(xs, ys)
# ax.plot(xs4, ys4)

# ax.plot(lung_1['Time'], lung_1['Observation'], 'bo', label='Dane')
# ax.plot(xs2, ys2, 'r-', label='Euler method', alpha=0.5)
# ax.plot(xs1, ys1, 'g-', label='Backward Euler method', alpha=0.5)
# ax.plot(xs3, ys3, 'o-', label='Taylor', alpha=0.2)
# ax.plot(xs6, ys6, 'p-', label='Midpoint', alpha=0.2)
# ax.plot(xs7, ys7, 'v-', label='Runge Kutta', alpha=0.2)
fig.legend()
plt.title('Id = 0')
plt.xlabel('Czas [dzień]')
plt.ylabel('Objętość guza [$mm^3$]')
# ys3[51], ys2[51]
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Objętość guza [$mm^3$]')

# %%
from scipy.optimize import curve_fit

# %%
def gompertz2(t, V0, r0, b):
    return V0 * np.exp(r0/b * (1 - np.exp(-b * t)))

# %%
list(lung_1.Time), lung_1['Observation'].to_numpy()
# Out:
# ([7.0, 11.0, 12.0, 13.0, 14.0, 15.0, 18.0, 19.0, 20.0],
#  array([  50.0217954 ,  309.51949325,  324.89587816,  450.8421203 ,
#          572.45081416,  664.33660565, 1151.69375372, 1338.38329876,
#         1522.8078487 ]))

# %%
popt, pcov = curve_fit(gompertz, lung_1['Time'], lung_1['Observation'])

# %%
fig, ax = plt.subplots()

ax.plot(lung_1['Time'], lung_1['Observation'], 'bo', label='Dane')


ax.plot(xs, gompertz(xs, *popt), 'b-')

# %%
lung_2 = lung_vol_data[lung_vol_data['ID'] == 1]



xs, ys = backward_euler_method(gompertz_diff, lung_2['Time'].iloc[0], lung_2['Observation'].iloc[0], h, int(n))
xs2, ys2 = euler_method(gompertz_diff, lung_2['Time'].iloc[0], lung_2['Observation'].iloc[0], h, int(n))


fig, ax = plt.subplots()
ax.plot(lung_2['Time'], lung_2['Observation'], 'bo', label='Dane')
ax.plot(xs2, ys2, 'r-', label='Euler method', alpha=0.5)
ax.plot(xs, ys, 'g-', label='Backward Euler method', alpha=0.5)
fig.legend()
plt.title('Id = 0')
plt.xlabel('Czas')
plt.ylabel('Objętość guza [$mm^3$]')
# Out:
# Text(0, 0.5, 'Objętość guza [$mm^3$]')

# %%
# Rozwiązywarka - lepsza

# %% [markdown]
# # <a id="porównanie">5. Porównanie modeli rozwoju guzów</a>

# %% [markdown]
# # <a id=wnioski>6. Wnioski</a>

# %% [markdown]
# ## Bibliografia:
#   [1] <span id="encyklopedia_def"> https://encyklopedia.pwn.pl/haslo/nowotwor;3948824.html</span> <br>
#     [2] <span id="rozwoj_kom">https://www.cancerfoundation.org.au/what-is-cancer-.html</span> <br>
#     [3] <span id="who">https://www.who.int/news-room/fact-sheets/detail/cancer </span><br>
#     [4] <span id="po_chemii">https://www.researchgate.net/figure/Represent-MRI-graphs-of-rectal-cancer-before-and-after-chemotherapy-in-the-same_fig1_278732051</span> <br>
#     [5] <span id="metody1">https://www.onkonet.pl/dp_infoslecz.php </span><br>
#     [6] <span id="davinci">https://www.onkonet.pl/n_n_piaseczno_davinci.php</span> <br>
#     [7] <span id="metody2">https://www.medicover.pl/nowotwory/metody-leczenia-nowotworow/ </span><br>
#     [8] <span id="nuklearna">https://www.wum.edu.pl/node/17674 </span><br>
#     [9] <span id="stats">https://onkologia.org.pl/sites/default/files/publications/2022-05/Nowotwory_2019.pdf</span> <br>
#     [10] <span id="gompertz">https://agro.icm.edu.pl/agro/element/bwmeta1.element.agro-article-cc915e9e-73e1-439a-bc93-fadfa37fb2ac/c/35-42.pdf</span> <br>
#     [11] <span id="myszki_fluo">https://zenodo.org/record/3593919</span> <br>
#     [12] <span id="myszki_piersi">https://zenodo.org/record/3574531</span> <br>
#     [13] <span id="piersi_badanie1">https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4148196/</span> <br>
#     [14] <span id="piersi_badanie2">https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5846333/</span> <br>
#     [15] <span id="myszki_obj">https://zenodo.org/records/3572401</span> <br>
#     [16] <span id="myszki_pluca">https://www.sciencedirect.com/science/article/abs/pii/0304383580901305?via%3Dihub</span> <br>
